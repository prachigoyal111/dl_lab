# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10

# %%
(X_train,y_train),(X_test,y_test)=cifar10.load_data()

X_train=X_train/255
X_test=X_test/255

model=models.Sequential()

# %%
model.add(layers.Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)))
model.add(layers.Conv2D(32,(3,3),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Flatten())

model.add(layers.Dense(128,activation='relu'))
model.add(layers.Dense(10,activation='softmax'))

# %%
model.compile(
optimizer='adam',
loss='sparse_categorical_crossentropy',
metrics=['accuracy']
)

model.fit(X_train,y_train,epochs=5,batch_size=64)

test_acc=model.evaluate(X_test,y_test)
# Out:
# Epoch 1/5
# 782/782 [==============================] - 128s 144ms/step - loss: 1.5075 - accuracy: 0.4545
# Epoch 2/5
# 782/782 [==============================] - 130s 167ms/step - loss: 1.1045 - accuracy: 0.6090
# Epoch 3/5
# 782/782 [==============================] - 124s 158ms/step - loss: 0.9209 - accuracy: 0.6778
# Epoch 4/5
# 782/782 [==============================] - 130s 166ms/step - loss: 0.7932 - accuracy: 0.7248
# Epoch 5/5
# 782/782 [==============================] - 134s 171ms/step - loss: 0.6996 - accuracy: 0.7568
# 313/313 [==============================] - 9s 9ms/step - loss: 0.8262 - accuracy: 0.7113

# %%
print(test_acc)
# Out:
# [0.8262284994125366, 0.7113000154495239]
